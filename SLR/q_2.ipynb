# %% [markdown]
# # Predicting vehicle emissions based on engine size.

# %%
import pandas as pd
from scipy.interpolate import pchip
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/PC/Desktop/Data Sets/co2 emissions/CO2 Emissions_Canada.csv",usecols=['Engine Size(L)','CO2 Emissions(g/km)'],nrows=50)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Engine Size(L)       50 non-null     float64
#  1   CO2 Emissions(g/km)  50 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 932.0 bytes

# %%
x = df[['Engine Size(L)']]
y = df['CO2 Emissions(g/km)']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

print(f"MAE: {mean_absolute_error(y_test,y_pred)}")
# Out:
# MAE: 27.42095351501721

# %%
plt.scatter(x_train,y_train,label="Actual Data",color="blue",edgecolors='green')
plt.plot(x_test,y_pred,label="Predicted values",color="red")
plt.grid(True)
plt.legend()
plt.show()
