# %%
import pandas as pd
from narwhals import read_csv
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/PC/Desktop/Data Sets/digital_marketing_campaign_dataset.csv",usecols=['AdSpend','WebsiteVisits'],nrows=250)
print(df)
x = df[['AdSpend']]
y = df['WebsiteVisits']
# Out:
#          AdSpend  WebsiteVisits
# 0    6497.870068              0
# 1    3898.668606             42
# 2    1546.429596              2
# 3     539.525936             47
# 4    1678.043573              0
# ..           ...            ...
# 245  9124.734938             10
# 246  1025.779358             49
# 247  5577.265953             41
# 248  6985.759360             37
# 249  2836.170129             23
#
# [250 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.5,random_state=42)

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

print(f"MAE: {mean_absolute_error(y_pred,y_test)}")
# Out:
# MAE: 12.285843968018337

# %%
plt.scatter(x,y,label="Actual data",color="blue")
plt.plot(x_test,y_pred,label="Predicted values",color="red")
plt.grid(True)
plt.legend()
plt.show()
