# %% [markdown]
# # Predicting housing price based on number of rooms.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/PC/Desktop/Data Sets/House Price vs Number of Rooms/HousingData.csv",usecols=['RM','MEDV'],nrows=100)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RM      100 non-null    float64
#  1   MEDV    100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
x = df[['RM']]
y = df['MEDV']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

print(f"MAE: {mean_absolute_error(y_test,y_pred)}")
# Out:
# MAE: 3.1780548052512474

# %%
plt.scatter(x_train,y_train,label="Actual Data",color="blue",edgecolors='green')
plt.plot(x_test,y_pred,label="Predicted values",color="red")
plt.grid(True)
plt.legend()
plt.show()
